# %%
# %load /Users/hwayment/ipynb_defaults.py
# %load_ext autoreload
# %autoreload 2

# %pylab inline
import numpy as np
import pandas as pd

import seaborn as sns
sns.set_style('white')
sns.set_context('poster')

from matplotlib.colors import LogNorm

from glob import glob
import os, sys, pickle, requests

from jupyter import draw_rna
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-121-23cceb510dd7> in <module>
#      16 import os, sys, pickle, requests
#      17
# ---> 18 from draw_rna.jupyter import draw_rna
#
# ModuleNotFoundError: No module named 'draw_rna.jupyter'

# %%
draw_rna(seq1,stc1)
draw_rna(seq2,stc2)

# %%
sys.path.append('./draw_rna')
from draw_rna.draw_rna import draw_rna

color = {'A': 'y', 'U':'b', 'G':'r', 'C':'g', 'T': 'b', 'N': 'k', ' ': 'w'}

def seq2col(seq):
    col = []
    for c in seq:
        col.append(color[c])
    return col

seq1 = 'GGAUGUACUACCAGCUGAUGAGUCCCAAAUAGGACGAAACGCC GGCGUCCUGGUAUCCAAUCC'
stc1 = '(((.(...(((((((....).((((......))))...(((((.))))).)))))).)...)))'

seq2 = 'GGGGAAAACCCC'
stc2 = '((((....))))'

draw_rna(seq1,stc1,seq2col(seq1))
draw_rna(seq2,stc2,seq2col(seq2))

# %%
f.get_figheight()
# Out:
# 12.0

# %%
scatter(0,0,s=300)
plt.text(0,0,'s',fontsize=20, verticalalignment='center',horizontalalignment='center',c='white')
# Out:
# Text(0, 0, 's')
