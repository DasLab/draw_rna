# %%
#autoreload for quick testing
# %load_ext autoreload
# %autoreload 2

from draw_rna.ipynb.draw import draw_struct
import numpy as np

seq = 'GGAUGUACUACCAGCUGAUGAGUCCCAAAUAGGACGAAACGCCAAAGGCGUCCUGGUAUCCAAUCC'
struct = '(((.(...(((((((....).((((......))))...(((((...))))).)))))).)...)))'

draw_struct(seq, struct)

# %%
# color with a random color vector!

draw_struct(seq, struct, c = np.random.uniform(size=len(seq)), cmap='viridis')
